# %%
import pandas as pd
import pymongo

df = pd.read_csv('insurance_claim_data.csv')
df.head()
# Out:
#   incident_severity insured_hobbies             incident_type  \
# 0      Major Damage        sleeping  Single Vehicle Collision
# 1      Minor Damage         reading             Vehicle Theft
# 2      Minor Damage     board-games   Multi-vehicle Collision
# 3      Major Damage     board-games  Single Vehicle Collision
# 4      Minor Damage     board-games             Vehicle Theft
#
#     collision_type incident_state authorities_contacted  property_claim  \
# 0   Side Collision             SC                Police           13020
# 1                ?             VA                Police             780
# 2   Rear Collision             NY                Police            3850
# 3  Front Collision             OH                Police            6340
# 4                ?             NY                   NaN             650
#
#    vehicle_claim  policy_annual_premium  insured_zip  policy_number  \
# 0          52080                1406.91       466132         521585
# 1           3510                1197.22       468176         342868
# 2          23100                1413.14       430632         687698
# 3          50720                1415.74       608117         227811
# 4           4550                1583.91       610706         367455
#
#    total_claim_amount  months_as_customer  injury_claim  age  \
# 0               71610                 328          6510   48
# 1                5070                 228           780   42
# 2               34650                 134          7700   29
# 3               63400                 256          6340   41
# 4                6500                 228          1300   44
#
#   insured_occupation  capital-gains fraud_reported
# 0       craft-repair          53300              Y
# 1  machine-op-inspct              0              Y
# 2              sales          35100              N
# 3       armed-forces          48900              Y
# 4              sales          66000              N

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')

# %%
DB_NAME = "Insurance_Prediction_Proj"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://<user_name>:<pass_word>@cluster0.qiyhijx.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from Mongodb
df = pd.DataFrame(list(collection.find()))
df.shape
# Out:
# (2000, 19)

# %%
df.head(3)
# Out:
#                         _id incident_severity insured_hobbies  \
# 0  69885fb0d0ef025ff748b5ad      Major Damage        sleeping
# 1  69885fb0d0ef025ff748b5ae      Minor Damage         reading
# 2  69885fb0d0ef025ff748b5af      Minor Damage     board-games
#
#               incident_type  collision_type incident_state  \
# 0  Single Vehicle Collision  Side Collision             SC
# 1             Vehicle Theft               ?             VA
# 2   Multi-vehicle Collision  Rear Collision             NY
#
#   authorities_contacted  property_claim  vehicle_claim  policy_annual_premium  \
# 0                Police           13020          52080                1406.91
# 1                Police             780           3510                1197.22
# 2                Police            3850          23100                1413.14
#
#    insured_zip  policy_number  total_claim_amount  months_as_customer  \
# 0       466132         521585               71610                 328
# 1       468176         342868                5070                 228
# 2       430632         687698               34650                 134
#
#    injury_claim  age insured_occupation  capital-gains fraud_reported
# 0          6510   48       craft-repair          53300              Y
# 1           780   42  machine-op-inspct              0              Y
# 2          7700   29              sales          35100              N
